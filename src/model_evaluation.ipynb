# %%
import numpy as np
import pandas as pd

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ### Evaluation Function

# %%
def evaluate_model(y_true, y_pred, model_name="Model"):
    """
    Evaluates regression model using MAE and RMSE
    """
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    print(f"📊 Evaluation Results for {model_name}")
    print(f"MAE  : {mae:.2f}")
    print(f"RMSE : {rmse:.2f}")
    
    return {"MAE": mae, "RMSE": rmse}

# %% [markdown]
# ### Load Prediction

# %%
y_test = pd.read_csv("../outputs/y_test.csv")
y_pred = pd.read_csv("../outputs/y_pred.csv")

# %% [markdown]
# ### Convert to 1D Array

# %%
y_test = y_test.values.ravel()
y_pred = y_pred.values.ravel()

# %% [markdown]
# ### Run Evaluation

# %%
results = evaluate_model(y_test, y_pred, model_name="Savings Prediction Model")
# Out:
# 📊 Evaluation Results for Savings Prediction Model
# MAE  : 118.41
# RMSE : 2216.50
